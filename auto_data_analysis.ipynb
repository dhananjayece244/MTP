# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_gyro = pd.read_csv('data/auto/2018-08-19_14-13-09/Gyroscope.csv')
df_acc = pd.read_csv('data/auto/2018-08-19_14-13-09/AccelerometerLinear.csv')
print("Acc.  shape -", df_acc.shape)
print("Gyro. shape -", df_gyro.shape)
print("Gyro columns", df_gyro.columns)
print("Acc  columns", df_acc.columns)
# Out:
# Acc.  shape - (8465, 4)
# Gyro. shape - (8488, 4)
# Gyro columns Index(['Milliseconds', 'X', 'Y', 'Z'], dtype='object')
# Acc  columns Index(['Milliseconds', 'X', 'Y', 'Z'], dtype='object')

# %%
df = df_acc
df.rename(columns={'X': 'AX', 'Y': 'AY', 'Z':'AZ'}, inplace=True)
df['GX'] = df_gyro['X']
df['GY'] = df_gyro['Y']
df['GZ'] = df_gyro['Z']

# %%
print("shape -", df.shape)
print("columns", df.columns)
df.head()
# Out:
# shape - (5000, 7)
# columns Index(['Milliseconds', 'AX', 'AY', 'AZ', 'GX', 'GY', 'GZ'], dtype='object')
#       Milliseconds        AX        AY        AZ        GX        GY        GZ
# 1000         10001 -0.872059 -0.057933  2.195639 -0.398834 -0.238770 -0.152145
# 1001         10012 -0.910380  0.027868  2.581983 -0.187912 -0.130112 -0.090363
# 1002         10021 -0.637063 -0.024763  1.653291  0.085861  0.048859 -0.032837
# 1003         10031 -0.254480 -0.033243 -0.218650  0.285065  0.193726 -0.009399
# 1004         10042 -0.235131  0.098974 -1.411173  0.272293  0.219299 -0.018997

# %%
df= df[1000:6000]
x_gyro = df['GX']
y_gyro = df['GY']
z_gyro = df['GZ']

x_acc = df['AX']
y_acc = df['AY']
z_acc = df['AZ']

# %%
x_gyro.plot(figsize=(20,4),  title="x-axis of gyro for auto")

# %%
y_gyro.plot(figsize=(20,4), title="y-axis of gyro for auto")

# %%
z_gyro.plot(figsize=(20,4), title="z-axis of gyro for auto")

# %%
x_acc.plot(figsize=(20,4),  title="x-axis of acc for auto")

# %%
y_acc.plot(figsize=(20,4),  title="y-axis of acc for auto")

# %%
z_acc.plot(figsize=(20,4), title="z-axis of acc for auto")
