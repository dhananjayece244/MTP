# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from pylab import rcParams
from sklearn import metrics
from sklearn.model_selection import train_test_split
from scipy.ndimage import gaussian_filter
# %matplotlib inline

# %%
def read_csv_file(acc, gyro, mode):
    df_gyro = pd.read_csv(gyro)
    df      = pd.read_csv(acc)
    df.rename(columns = {'X': 'AX', 'Y':'AY', 'Z':'AZ'}, inplace = True)
    df['GX'] = df_gyro['X']
    df['GY'] = df_gyro['Y']
    df['GZ'] = df_gyro['Z']
    
    df['activity'] = mode
    return df

# %%
def plot_transportation_mod(transportation_mode, df):
    data = df[df['activity'] == transportation_mode][['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']][:8000]
    
    axis = data.plot(subplots = True, figsize =(20, 20), title = transportation_mode)
    
    for ax in axis:
        ax.legend(loc = 'lower left', bbox_to_anchor=(1.0,0.5))

# %%
def GaussianFilter(df, window_length):
    df1 = df
    df1['fAX'] = gaussian_filter(df['AX'], window_length)
    df1['fAY'] = gaussian_filter(df['AY'], window_length)
    df1['fAZ'] = gaussian_filter(df['AZ'], window_length)

    df1['fGX'] = gaussian_filter(df['GX'], window_length)
    df1['fGY'] = gaussian_filter(df['GY'], window_length)
    df1['fGZ'] = gaussian_filter(df['GZ'], window_length)
    
    return df1

# %%
acc_file = 'data/Bike0903/2018-09-03_15-53-27/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_15-53-27/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[1000:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()



df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')

df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian gilter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')

acc_file = 'data/Bike0903/2018-09-03_16-03-12/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_16-03-12/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[1000:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()


df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')

df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian filter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')
# Out:
# shape - (10831, 9)
# shape - (8000, 9)
# shape - (10432, 9)
# shape - (8000, 9)
# Text(0,0.5,'Amplitude ($rad/s$)')

# %%
acc_file = 'data/Bike0903/2018-09-03_16-16-05/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_16-16-05/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[200:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()

df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')

df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian gilter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')

acc_file = 'data/Bike0903/2018-09-03_15-58-17/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_15-58-17/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[200:10000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()

df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')

df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian filter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')
# Out:
# shape - (10889, 9)
# shape - (8800, 9)
# shape - (11674, 9)
# shape - (9800, 9)
# Text(0,0.5,'Amplitude ($rad/s$)')

# %%
acc_file = 'data/Bike0903/2018-09-03_16-12-17/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_16-12-17/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[500:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()

df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')


df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian filter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')

acc_file = 'data/Bike0903/2018-09-03_15-53-27/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_15-53-27/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)


df = df[1000:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()

df = GaussianFilter(df, 5)
df['AccMean'] = (df['AX'] + df['AY'] + df['AZ'])/3
df['GyroMean'] = (df['GX'] + df['GY'] + df['GZ'])/3

# df[['GZ','fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro.for bike")
# plt.xlabel('Time')
# plt.ylabel('Amplitude ($rad/s$)')

df[['fGZ']].plot(figsize = (20,4), title = "Z-axis of gyro. after using gaussian filter for bike")
plt.xlabel('Time')
plt.ylabel('Amplitude ($rad/s$)')
# Out:
# shape - (10141, 9)
# shape - (8500, 9)
# shape - (10831, 9)
# shape - (8000, 9)
# Text(0,0.5,'Amplitude ($rad/s$)')

# %%
acc_file = 'data/Bike0903/2018-09-03_16-19-50/AccelerometerLinear.csv'
gyro_file= 'data/Bike0903/2018-09-03_16-19-50/Gyroscope.csv'

df = read_csv_file(acc_file, gyro_file, 'bike')
print("shape -", df.shape)

df = df[200:9000]
df.reset_index(drop = True, inplace = True)
print("shape -", df.shape)
df.head()
# Out:
# shape - (4, 9)
# shape - (0, 9)
# Empty DataFrame
# Columns: [Timestamp, Milliseconds, AX, AY, AZ, GX, GY, GZ, activity]
# Index: []
