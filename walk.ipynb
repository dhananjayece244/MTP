# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from pylab import rcParams
from sklearn import metrics
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
sns.set(style ='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
columns = ['timestamp', 'AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']

# %%
df_gyro = pd.read_csv('data/walk/2018-08-19_17-19-20/Gyroscope.csv')
df = pd.read_csv('data/walk/2018-08-19_17-19-20/AccelerometerLinear.csv')

df.rename(columns={'X': 'AX', 'Y': 'AY', 'Z':'AZ'}, inplace=True)
df['GX'] = df_gyro['X']
df['GY'] = df_gyro['Y']
df['GZ'] = df_gyro['Z']
df['user'] = 1
df['activity']='walk'

print("shape -", df.shape)

# df= df[1000:3500]


df.head()
# Out:
# shape - (2659, 9)
#    Milliseconds        AX        AY        AZ        GX        GY        GZ  \
# 0             1 -0.004058 -0.143530 -0.607077  0.312958  0.279755  0.297577
# 1            21  0.261535 -0.065555 -1.419880  0.127609 -0.019577  0.281586
# 2            40  0.422314 -0.274906 -1.232827 -0.341110 -0.022781  0.225128
# 3            60  0.190740 -0.330172 -0.365795 -0.468933  0.166840  0.223007
# 4            81 -0.124816 -0.256056  0.373999 -0.298492  0.444870  0.290115
#
#    user activity
# 0     1     walk
# 1     1     walk
# 2     1     walk
# 3     1     walk
# 4     1     walk

# %%
# df['activity'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
# df['user'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
def plot_transportation_mod(transportation_mode, df):
    data = df[df['activity'] == transportation_mode][['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']][:8000]
    
    axis = data.plot(subplots = True, figsize =(20, 20), title = transportation_mode)
    
    for ax in axis:
        ax.legend(loc = 'lower left', bbox_to_anchor=(1.0,0.5))

# %%
plot_transportation_mod('walk', df)
