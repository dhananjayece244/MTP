# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from pylab import rcParams
from sklearn import metrics
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
sns.set(style ='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
columns = ['timestamp', 'AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']

# %%
df_gyro = pd.read_csv('data/Cycle/2018-08-20_12-59-18/Gyroscope.csv')

df = pd.read_csv('data/Cycle/2018-08-20_12-59-18/AccelerometerLinear.csv')

df.rename(columns={'X': 'AX', 'Y': 'AY', 'Z':'AZ'}, inplace=True)
df['GX'] = df_gyro['X']
df['GY'] = df_gyro['Y']
df['GZ'] = df_gyro['Z']
df['user'] = 1
df['activity']='cycle'
print("shape -", df.shape)
df= df[2000:4500]


df.head()
# Out:
# shape - (12448, 9)
#       Milliseconds        AX        AY        AZ        GX        GY  \
# 2000         40002  3.453875  2.447770 -5.079762  0.483856 -0.342224
# 2001         40021  0.080547  0.598871 -4.393107  0.053482 -0.849289
# 2002         40041 -3.767822 -3.760437 -3.633322 -0.490860  0.605865
# 2003         40062 -1.775900 -2.805123  3.192133 -0.564377  0.996826
# 2004         40081 -0.766884 -1.057720  4.757971 -0.097778  0.040207
#
#             GZ  user activity
# 2000  2.200394     1    cycle
# 2001  2.502930     1    cycle
# 2002  2.557251     1    cycle
# 2003  2.069367     1    cycle
# 2004  1.839264     1    cycle

# %%
# df['activity'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
# df['user'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
def plot_transportation_mod(transportation_mode, df):
    data = df[df['activity'] == transportation_mode][['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']][:8000]
    
    axis = data.plot(subplots = True, figsize =(20, 20), title = transportation_mode)
    
    for ax in axis:
        ax.legend(loc = 'lower left', bbox_to_anchor=(1.0,0.5))

# %%
plot_transportation_mod('cycle', df)
