# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from pylab import rcParams
from sklearn import metrics
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
sns.set(style ='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
columns = ['timestamp', 'AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']

# %%
df_gyro = pd.read_csv('data/auto/2018-08-19_14-13-09/Gyroscope.csv')
df = pd.read_csv('data/auto/2018-08-19_14-13-09/AccelerometerLinear.csv')

df.rename(columns={'X': 'AX', 'Y': 'AY', 'Z':'AZ'}, inplace=True)
df['GX'] = df_gyro['X']
df['GY'] = df_gyro['Y']
df['GZ'] = df_gyro['Z']
df['user'] = 1
df['activity']='auto'

print("shape -", df.shape)

df= df[1000:3500]


df.head()
# Out:
# shape - (8465, 9)
#       Milliseconds        AX        AY        AZ        GX        GY  \
# 1000         10001 -0.872059 -0.057933  2.195639 -0.398834 -0.238770
# 1001         10012 -0.910380  0.027868  2.581983 -0.187912 -0.130112
# 1002         10021 -0.637063 -0.024763  1.653291  0.085861  0.048859
# 1003         10031 -0.254480 -0.033243 -0.218650  0.285065  0.193726
# 1004         10042 -0.235131  0.098974 -1.411173  0.272293  0.219299
#
#             GZ  user activity
# 1000 -0.152145     1     auto
# 1001 -0.090363     1     auto
# 1002 -0.032837     1     auto
# 1003 -0.009399     1     auto
# 1004 -0.018997     1     auto

# %%
# df['activity'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
# df['user'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
def plot_transportation_mod(transportation_mode, df):
    data = df[df['activity'] == transportation_mode][['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']][:8000]
    
    axis = data.plot(subplots = True, figsize =(20, 20), title = transportation_mode)
    
    for ax in axis:
        ax.legend(loc = 'lower left', bbox_to_anchor=(1.0,0.5))

# %%
plot_transportation_mod('auto', df)
