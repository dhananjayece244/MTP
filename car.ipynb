# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from pylab import rcParams
from sklearn import metrics
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
sns.set(style ='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
columns = ['timestamp', 'AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']

# %%
df_gyro = pd.read_csv('data/car/2018-08-17_16-50-00/Gyroscope.csv')

df = pd.read_csv('data/car/2018-08-17_16-50-00/AccelerometerLinear.csv')

df.rename(columns={'X': 'AX', 'Y': 'AY', 'Z':'AZ'}, inplace=True)
df['GX'] = df_gyro['X']
df['GY'] = df_gyro['Y']
df['GZ'] = df_gyro['Z']
df['user'] = 1
df['activity']='car'
print("shape -", df.shape)

df= df[1000:6000]
print("shape -", df.shape)

df.head()
# Out:
# shape - (13444, 9)
# shape - (5000, 9)
#       Milliseconds        AX        AY        AZ        GX        GY  \
# 1000         20002  1.023843  1.882091 -3.214577  0.082123 -0.210190
# 1001         20021 -1.151717  0.362426  4.660689  0.000092  0.095551
# 1002         20042 -0.921100 -0.142955 -2.822214 -0.006302  0.060394
# 1003         20061 -1.087476  1.375160  0.624154  0.012878 -0.105789
# 1004         20082 -0.243528  1.180786 -0.197870 -0.175674 -0.064240
#
#             GZ  user activity
# 1000  0.011200     1      car
# 1001 -0.006912     1      car
# 1002 -0.011169     1      car
# 1003  0.006943     1      car
# 1004  0.009064     1      car

# %%
# df['activity'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
# df['user'].value_counts().plot(kind = 'bar', title = 'counts of activities')

# %%
def plot_transportation_mod(transportation_mode, df):
    data = df[df['activity'] == transportation_mode][['AX', 'AY', 'AZ', 'GX', 'GY', 'GZ']][:8000]
    
    axis = data.plot(subplots = True, figsize =(20, 20), title = transportation_mode)
    
    for ax in axis:
        ax.legend(loc = 'lower left', bbox_to_anchor=(1.0,0.5))

# %%
plot_transportation_mod('car', df)
